# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
import requests

import pandas as pd

import json

from stackapi import StackAPI

import datetime as dt

SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1547247600, todate=1577833200, min=20, tagged='python', sort='votes')

print(json.dumps(questions, indent=4))
# Out:
# {
#     "backoff": 0,
#     "has_more": false,
#     "page": 2,
#     "quota_max": 300,
#     "quota_remaining": 300,
#     "total": 0,
#     "items": [
#         {
#             "tags": [
#                 "python",
#                 "math",
#                 "hash",
#                 "floating-point",
#                 "pi"
#             ],
#             "owner": {
#                 "reputation": 216292,
#                 "user_id": 674039,
#                 "user_type": "registered",
#                 "accept_rate": 94,
#                 "profile_image": "https://i.stack.imgur.com/leoFi.gif?s=128&g=1",
#                 "display_name": "wim",
#                 "link": "https://stackoverflow.com/users/674039/wim"
#             },
#             "is_answered": true,
#             "view_count": 27345,
#             "accepted_answer_id": 56227651,
#             "answer_count": 3,
#             "score": 240,
#             "last_activity_date": 1559184912,
# ...

# %%
# stack_api = comments.json()

# %%
question_dec = pd.DataFrame(questions)

question_dec
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0     False     2        300              300      0
# 1          0     False     2        300              300      0
# 2          0     False     2        300              300      0
# 3          0     False     2        300              300      0
# 4          0     False     2        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 104        0     False     2        300              300      0
# 105        0     False     2        300              300      0
# 106        0     False     2        300              300      0
# 107        0     False     2        300              300      0
# 108        0     False     2        300              300      0
#
#                                                  items
# 0    {'tags': ['python', 'math', 'hash', 'floating-...
# 1    {'tags': ['python', 'tensorflow', 'keras', 'pe...
# ...

# %%
question_dec['items']
# Out:
# 0      {'tags': ['python', 'math', 'hash', 'floating-...
# 1      {'tags': ['python', 'tensorflow', 'keras', 'pe...
# 2      {'tags': ['python', 'python-3.x', 'string', 'f...
# 3      {'tags': ['python', 'boolean-logic'], 'owner':...
# 4      {'tags': ['python', 'for-loop', 'indexing'], '...
#                              ...
# 104    {'tags': ['python', 'list'], 'owner': {'reputa...
# 105    {'tags': ['python', 'django', 'architecture', ...
# 106    {'tags': ['python', 'python-asyncio', 'gevent'...
# 107    {'tags': ['python', 'tensorflow', 'keras', 'te...
# 108    {'tags': ['python', 'tensorflow', 'deep-learni...
# Name: items, Length: 109, dtype: object

# %%
s  = pd.DataFrame.from_dict(question_dec, orient='index')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-b2f616edc88c> in <module>
# ----> 1 s  = pd.DataFrame.from_dict(question_dec, orient='index')
#
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1191             if len(data) > 0:
#    1192                 # TODO speed up Series case
# -> 1193                 if isinstance(list(data.values())[0], (Series, dict)):
#    1194                     data = _from_nested_dict(data)
#    1195                 else:
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
question_d = pd.DataFrame(question_dec['items'])

# %%
# Out:
#                                                  items
# 0    {'tags': ['python', 'math', 'hash', 'floating-...
# 1    {'tags': ['python', 'tensorflow', 'keras', 'pe...
# 2    {'tags': ['python', 'python-3.x', 'string', 'f...
# 3    {'tags': ['python', 'boolean-logic'], 'owner':...
# 4    {'tags': ['python', 'for-loop', 'indexing'], '...
# ..                                                 ...
# 104  {'tags': ['python', 'list'], 'owner': {'reputa...
# 105  {'tags': ['python', 'django', 'architecture', ...
# 106  {'tags': ['python', 'python-asyncio', 'gevent'...
# 107  {'tags': ['python', 'tensorflow', 'keras', 'te...
# 108  {'tags': ['python', 'tensorflow', 'deep-learni...
#
# [109 rows x 1 columns]

# %%
question_dec['items'][0]
# Out:
# {'tags': ['python', 'math', 'hash', 'floating-point', 'pi'],
#  'owner': {'reputation': 216292,
#   'user_id': 674039,
#   'user_type': 'registered',
#   'accept_rate': 94,
#   'profile_image': 'https://i.stack.imgur.com/leoFi.gif?s=128&g=1',
#   'display_name': 'wim',
#   'link': 'https://stackoverflow.com/users/674039/wim'},
#  'is_answered': True,
#  'view_count': 27345,
#  'accepted_answer_id': 56227651,
#  'answer_count': 3,
#  'score': 240,
#  'last_activity_date': 1559184912,
#  'creation_date': 1558382420,
#  'last_edit_date': 1558661066,
#  'question_id': 56227419,
#  'link': 'https://stackoverflow.com/questions/56227419/why-does-pythons-hash-of-infinity-have-the-digits-of-%cf%80',
#  'title': 'Why does Python&#39;s hash of infinity have the digits of π?'}

# %%
question_dec['items'][0]['question_id']
# Out:
# 56227419

# %%
def flatten3(df):
    for k,v in df['items'][0].items():
        column_name = 'items' + '_' + k
        print(column_name)
        print(v)
    df[column_name] = v

# %%
flatten3(question_d)
# Out:
# items_tags
# ['python', 'math', 'hash', 'floating-point', 'pi']
# items_owner
# {'reputation': 216292, 'user_id': 674039, 'user_type': 'registered', 'accept_rate': 94, 'profile_image': 'https://i.stack.imgur.com/leoFi.gif?s=128&g=1', 'display_name': 'wim', 'link': 'https://stackoverflow.com/users/674039/wim'}
# items_is_answered
# True
# items_view_count
# 27345
# items_accepted_answer_id
# 56227651
# items_answer_count
# 3
# items_score
# 240
# items_last_activity_date
# 1559184912
# items_creation_date
# 1558382420
# items_last_edit_date
# 1558661066
# items_question_id
# 56227419
# items_link
# https://stackoverflow.com/questions/56227419/why-does-pythons-hash-of-infinity-have-the-digits-of-%cf%80
# items_title
# Why does Python&#39;s hash of infinity have the digits of π?

# %%
question_dec
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0     False     2        300              300      0
# 1          0     False     2        300              300      0
# 2          0     False     2        300              300      0
# 3          0     False     2        300              300      0
# 4          0     False     2        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 104        0     False     2        300              300      0
# 105        0     False     2        300              300      0
# 106        0     False     2        300              300      0
# 107        0     False     2        300              300      0
# 108        0     False     2        300              300      0
#
#                                                  items  \
# 0    {'tags': ['python', 'math', 'hash', 'floating-...
# 1    {'tags': ['python', 'tensorflow', 'keras', 'pe...
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
flatten(question_dec, question_dec['items'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-142bb32b65cc> in <module>
# ----> 1 flatten(question_dec, question_dec['items'])
#
# <ipython-input-55-c0a2c242ca86> in flatten(data, col_list)
#       1 def flatten(data, col_list):
#       2     for column in col_list:
# ----> 3         flattened = pd.DataFrame(dict(data[column])).transpose()
#       4         columns = [str(col) for col in flattened.columns]
#       5         flattened.columns = [column + '_' + colname for colname in columns]
#
# c:\users\binardo surface\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
# ...

# %%
def flatten2(data, col_list):
    for column in data['items'][0].items():
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
def flatten4(df):
    for column in df['items'][0].items():
        flattened = pd.DataFrame(dict(df[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
nested_columns = ['items', 'items_title']

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
list_titles = []
for i in range(500):
    list_titles.append(questions['items'][i]["title"])
    
list_titles
# Out:
# ['Calling a scenario in another feature file by scenario name',
#  'JTextPane won&#39;t wrap',
#  'Why is regex matching very slow?',
#  'Self created templates not shown in the &quot;New Project&quot; dialog in the Visual Studio 2019',
#  'Yarn requires Node.js 4.0 or higher and not executing scripts',
#  'Problem to have access to jquery plugin inside $(document).ready() with django-debug-toolbar',
#  'libvips Nearest Neighbor / Bicubic Deep Zoom Pyramid Creation',
#  'ReadOnlySequence&lt;char&gt; conversion from ReadOnlySequence&lt;byte&gt;?',
#  'Custom Next.js - difference between getRequestHandler and render functions',
#  'Firebase authentication error google sign in',
#  'Why this if(s[j]==s[i] &amp;&amp; i&gt;0) condition is not work for this [{()}]',
#  'Unable to import from Shared mail box (Microsoft Exchange Online)',
#  'How can I run tcpdump command with a script?',
#  'Displaying contours for Chi square value in R',
# ...

# %%
questions['items'][0]["title"]

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
